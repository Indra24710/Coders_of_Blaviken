# %% [markdown]
# **Google Drive connection setup**

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My\ Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content/drive/My Drive

# %%
# !pip install -r requirements.txt

# %% [markdown]
# **Kaggle API setup**

# %%
# !pip install kaggle
#! mkdir ~/.kaggle
# import json
# token = {"username":"indrakumar24710","key":"c054bd301cfefda31ec96e3936c5609e"}
# with open('/content/kaggle/kaggle.json', 'w') as file:
#     json.dump(token, file)
# !cp /content/kaggle/kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# !kaggle datasets list

# %% [markdown]
# **Downloading and extracting the face dataset**

# %%
# !kaggle datasets download -d atulanandjha/lfwpeople
# %cd drive/My\ Drive
from zipfile import ZipFile
file_name = "facenet_test.zip"
  
with ZipFile(file_name, 'r') as zip: 
    zip.printdir() 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!') 
# import tarfile
# fname='lfw-funneled.tgz'
# if fname.endswith("tgz"):
#     tar = tarfile.open('lfw-funneled.tgz', "r:gz")
#     tar.extractall()
#     tar.close()
# elif fname.endswith("tar"):
#     tar = tarfile.open('lfw-funneled.tgz', "r:")
#     tar.extractall()
#     tar.close()

# %% [markdown]
# **Dataset Information**

# %%
import os
print(len(os.listdir('lfw_funneled')))
# Out:
# 5760

# %%
print('Length of train dataset: ',len(os.listdir('lfw_funneled')))
print('Length of test dataset: ',len(os.listdir('facenet_test')))
# Out:
# Length of train dataset:  5760
# Length of test dataset:  1620

# %%
import os
import shutil
count=0

for i in os.listdir('lfw_funneled'):
  try:
    if len(os.listdir('lfw_funneled/'+i))>5 and len(os.listdir('lfw_funneled/'+i))<40:
      #shutil.move('lfw_funneled/'+i,'facenet_train/'+i)
      count+=1
  except:
    pass



print(count)

# %%
import shutil
import os
test=[]
for i in os.listdir('facenet_train'):
  try:
    shutil.move('facenet_train/'+i+'/'+os.listdir('facenet_train/'+i)[0],'facenet_test/'+os.listdir('facenet_train/'+i)[0])
    test.append([i,os.listdir('facenet_train/'+i)[0]])
    
  except:
    pass

# %%
test

# %% [markdown]
# **Training the Face recognition model**

# %%
# !chmod +x tasks/train.sh
# !./tasks/train.sh 'facenet_train'
# Out:
# facenet_train/0/George_HW_Bush_0001.jpg
# facenet_train/0/George_HW_Bush_0002.jpg
# facenet_train/0/George_HW_Bush_0003.jpg
# facenet_train/0/George_HW_Bush_0004.jpg
# facenet_train/0/George_HW_Bush_0005.jpg
# facenet_train/0/George_HW_Bush_0006.jpg
# facenet_train/0/George_HW_Bush_0008.jpg
# facenet_train/0/George_HW_Bush_0009.jpg
# facenet_train/0/George_HW_Bush_0010.jpg
# facenet_train/0/George_HW_Bush_0011.jpg
# facenet_train/0/George_HW_Bush_0012.jpg
# facenet_train/0/George_HW_Bush_0013.jpg
# facenet_train/1/Michael_Schumacher_0001.jpg
# facenet_train/1/Michael_Schumacher_0003.jpg
# facenet_train/1/Michael_Schumacher_0004.jpg
# facenet_train/1/Michael_Schumacher_0005.jpg
# facenet_train/1/Michael_Schumacher_0006.jpg
# facenet_train/1/Michael_Schumacher_0007.jpg
# facenet_train/1/Michael_Schumacher_0008.jpg
# facenet_train/1/Michael_Schumacher_0009.jpg
# facenet_train/1/Michael_Schumacher_0010.jpg
# facenet_train/1/Michael_Schumacher_0011.jpg
# ...

# %%
# !python -m inference.classifier --image-path 'facenet_test'

# %% [markdown]
# **Id's and Images**

# %%
test=[['0', 'George_HW_Bush_0010.jpg'],
 ['1', 'Michael_Schumacher_0004.jpg'],
 ['2', 'Paul_ONeill_0003.jpg'],
 ['3', 'John_Manley_0007.jpg'],
 ['4', 'Tiger_Woods_0022.jpg'],
 ['5', 'Arminio_Fraga_0004.jpg'],
 ['6', 'Gordon_Brown_0005.jpg'],
 ['7', 'Igor_Ivanov_0018.jpg'],
 ['8', 'Li_Peng_0001.jpg'],
 ['9', 'John_Howard_0017.jpg'],
 ['10', 'Bob_Graham_0004.jpg'],
 ['11', 'Tommy_Haas_0004.jpg'],
 ['12', 'Pervez_Musharraf_0010.jpg'],
 ['13', 'JK_Rowling_0002.jpg'],
 ['14', 'Edmund_Stoiber_0013.jpg'],
 ['15', 'Bill_Clinton_0001.jpg'],
 ['16', 'Yoko_Ono_0003.jpg'],
 ['17', 'Larry_Brown_0004.jpg'],
 ['18', 'Michael_Chang_0008.jpg'],
 ['19', 'James_Kelly_0003.jpg'],
 ['20', 'Ann_Veneman_0007.jpg'],
 ['21', 'Jose_Serra_0005.jpg'],
 ['22', 'Justin_Timberlake_0004.jpg'],
 ['23', 'Lance_Armstrong_0015.jpg'],
 ['24', 'Tom_Daschle_0006.jpg'],
 ['25', 'Shimon_Peres_0004.jpg'],
 ['26', 'Bill_McBride_0007.jpg'],
 ['27', 'Vojislav_Kostunica_0002.jpg'],
 ['28', 'Atal_Bihari_Vajpayee_0020.jpg'],
 ['29', 'Jackie_Chan_0003.jpg'],
 ['30', 'Kofi_Annan_0017.jpg'],
 ['31', 'Alejandro_Toledo_0012.jpg'],
 ['32', 'Robert_Duvall_0004.jpg'],
 ['33', 'Bill_Simon_0015.jpg'],
 ['34', 'Sergio_Vieira_De_Mello_0009.jpg'],
 ['35', 'Hamid_Karzai_0012.jpg'],
 ['36', 'Sophia_Loren_0003.jpg'],
 ['37', 'Ray_Romano_0004.jpg'],
 ['38', 'Albert_Costa_0004.jpg'],
 ['39', 'Megawati_Sukarnoputri_0005.jpg'],
 ['40', 'George_Clooney_0007.jpg'],
 ['41', 'Vicente_Fox_0007.jpg'],
 ['42', 'Mohammad_Khatami_0009.jpg'],
 ['43', 'Hans_Blix_0004.jpg'],
 ['44', 'Roman_Polanski_0001.jpg'],
 ['45', 'Hillary_Clinton_0013.jpg'],
 ['46', 'Amelie_Mauresmo_0003.jpg'],
 ['47', 'Pete_Sampras_0020.jpg'],
 ['48', 'Andre_Agassi_0025.jpg'],
 ['49', 'Saddam_Hussein_0002.jpg'],
 ['50', 'Tang_Jiaxuan_0002.jpg'],
 ['51', 'Yoriko_Kawaguchi_0008.jpg'],
 ['52', 'Taha_Yassin_Ramadan_0004.jpg'],
 ['53', 'Condoleezza_Rice_0004.jpg'],
 ['54', 'Justine_Pasek_0001.jpg'],
 ['55', 'John_Travolta_0001.jpg'],
 ['56', 'Fernando_Henrique_Cardoso_0001.jpg'],
 ['57', 'Alvaro_Uribe_0021.jpg'],
 ['238', 'Bill_Gates_0003.jpg'],
 ['239', 'Maria_Shriver_0007.jpg'],
 ['240', 'Sheryl_Crow_0005.jpg'],
 ['241', 'Zinedine_Zidane_0004.jpg'],
 ['242', 'John_Allen_Muhammad_0008.jpg'],
 ['243', 'Abdullah_Gul_0012.jpg'],
 ['244', 'Thaksin_Shinawatra_0005.jpg'],
 ['245', 'Antonio_Palocci_0001.jpg'],
 ['246', 'Rick_Perry_0005.jpg'],
 ['247', 'Kamal_Kharrazi_0003.jpg'],
 ['248', 'Bill_Graham_0008.jpg'],
 ['249', 'Jon_Gruden_0007.jpg'],
 ['250', 'Paul_Bremer_0002.jpg'],
 ['251', 'Ricardo_Sanchez_0005.jpg'],
 ['252', 'Guillermo_Coria_0026.jpg'],
 ['253', 'Luis_Ernesto_Derbez_Bautista_0003.jpg'],
 ['254', 'Jean_Charest_0004.jpg'],
 ['255', 'Valery_Giscard_dEstaing_0003.jpg'],
 ['256', 'Amelia_Vega_0002.jpg'],
 ['257', 'Paul_Wolfowitz_0004.jpg'],
 ['258', 'Li_Zhaoxing_0005.jpg'],
 ['259', 'Nestor_Kirchner_0036.jpg'],
 ['260', 'Joan_Laporta_0003.jpg'],
 ['261', 'Wen_Jiabao_0008.jpg'],
 ['262', 'Roger_Federer_0005.jpg'],
 ['263', 'Thomas_OBrien_0006.jpg'],
 ['264', 'John_Abizaid_0003.jpg'],
 ['265', 'Dominique_de_Villepin_0005.jpg'],
 ['266', 'Bob_Hope_0003.jpg'],
 ['267', 'Ben_Affleck_0007.jpg'],
 ['268', 'Mark_Philippoussis_0008.jpg'],
 ['269', 'Dennis_Kucinich_0004.jpg'],
 ['270', 'Charles_Taylor_0005.jpg'],
 ['271', 'Jason_Kidd_0007.jpg'],
 ['272', 'Kevin_Costner_0008.jpg'],
 ['273', 'Ralf_Schumacher_0004.jpg'],
 ['274', 'Jim_Furyk_0005.jpg'],
 ['275', 'Norah_Jones_0014.jpg'],
 ['276', 'Geoff_Hoon_0001.jpg'],
 ['277', 'Jay_Garner_0004.jpg'],
 ['278', 'Jose_Manuel_Durao_Barroso_0006.jpg'],
 ['279', 'Clay_Aiken_0003.jpg'],
 ['280', 'Adrien_Brody_0011.jpg'],
 ['281', 'Roy_Moore_0003.jpg'],
 ['282', 'Holly_Hunter_0003.jpg'],
 ['283', 'Luis_Horna_0003.jpg'],
 ['284', 'Julie_Gerberding_0013.jpg'],
 ['285', 'Meryl_Streep_0005.jpg'],
 ['286', 'Rob_Marshall_0003.jpg'],
 ['287', 'Gunter_Pleuger_0006.jpg'],
 ['288', 'Diana_Krall_0006.jpg'],
 ['289', 'Ron_Dittemore_0001.jpg'],
 ['290', 'Vincent_Brooks_0006.jpg'],
 ['291', 'Edward_Lu_0005.jpg'],['292','Indra Kumar V']]

# %%
Justine_Pasek_0003.jpg', '54'], ['Condoleezza_Rice_0006.jpg', '53'], ['Alvaro_Uribe_0002.jpg', '57'], ['Taha_Yassin_Ramadan_0008.jpg', '52'], ['Yoriko_Kawaguchi_0003.jpg', '51'], ['Tang_Jiaxuan_0006.jpg', '50'], ['Saddam_Hussein_0001.jpg', '49'], ['Andre_Agassi_0007.jpg', '48'], ['Pete_Sampras_0003.jpg', '47'], ['Amelie_Mauresmo_0016.jpg', '46'], ['Roman_Polanski_0006.jpg', '44'], ['Hillary_Clinton_0004.jpg', '45'], ['Mohammad_Khatami_0005.jpg', '42'], ['Vicente_Fox_0014.jpg', '41'], ['Hans_Blix_0005.jpg', '43'], ['Albert_Costa_0003.jpg', '38'], ['George_Clooney_0006.jpg', '40'], ['Ray_Romano_0006.jpg', '37'], ['Sophia_Loren_0001.jpg', '36'], ['Megawati_Sukarnoputri_0003.jpg', '39'], ['Megawati_Sukarnoputri_0003.jpg', '18'], ['Hamid_Karzai_0013.jpg', '35'], ['Sergio_Vieira_De_Mello_0001.jpg', '34'], ['Bill_Simon_0003.jpg', '33'], ['Robert_Duvall_0007.jpg', '32'], ['Alejandro_Toledo_0036.jpg', '31'], ['Kofi_Annan_0008.jpg', '30'], ['Jackie_Chan_0002.jpg', '29'], ['Vojislav_Kostunica_0004.jpg', '27'], ['Atal_Bihari_Vajpayee_0007.jpg', '28'], ['Bill_McBride_0010.jpg', '26'], ['Shimon_Peres_0002.jpg', '25'], ['Shimon_Peres_0002.jpg', '93'], ['Tom_Daschle_0008.jpg', '24'], ['Lance_Armstrong_0011.jpg', '23'], ['Justin_Timberlake_0002.jpg', '22'], ['Justin_Timberlake_0002.jpg', '270'], ['Jose_Serra_0008.jpg', '21'], ['Ann_Veneman_0005.jpg', '20'], ['James_Kelly_0011.jpg', '19'], ['Michael_Chang_0004.jpg', '18'], ['Larry_Brown_0007.jpg', '17'], ['Yoko_Ono_0002.jpg', '16'], ['Edmund_Stoiber_0006.jpg', '14'], ['JK_Rowling_0006.jpg', '13'], ['Bill_Clinton_0004.jpg', '15'], ['Tommy_Haas_0006.jpg', '11'], ['Pervez_Musharraf_0004.jpg', '12'], ['Bob_Graham_0002.jpg', '10'], ['John_Howard_0015.jpg', '9'], ['Li_Peng_0009.jpg', '8'], ['Igor_Ivanov_0004.jpg', '7'], ['Gordon_Brown_0001.jpg', '6'], ['Arminio_Fraga_0003.jpg', '5'], ['Tiger_Woods_0007.jpg', '4'], ['John_Manley_0002.jpg', '3'], ['Paul_ONeill_0005.jpg', '2'], ['Michael_Schumacher_0002.jpg', '1'], ['George_HW_Bush_0007.jpg', '0']]
s

# %%
corr=0
for i in s:
  name=''
  for ch in i[0]:
    if ch.isnumeric()==1:
      break
    name+=ch
  for j in test:
    if ch in j[1]:
      if j[0]==i[1]:
        corr+=1
corr
# Out:
# 333

# %%
len(s)
# Out:
# 334

# %%
print('test accuracy: ',str(corr/len(s)))

# %%
import os
for i in os.listdir('facenet_test'):
  #new=int(i)
  #new+=12
  #os.rename('facenet_test/'+i,'facenet_test/'+str(new))
  print(i)
# Out:
# 24
# 125
# 158
# 27
# 166
# 226
# 233
# 250
# 274
# 42
# 16
# 96

# %%
criminal_data=[]
for i in test:
  ch=''
  for j in i[1]:
    if j.isnumeric()==1:
      break
    ch+=j
  #print(ch[0:-1])
  criminal_data.append([i[0],ch[0:-1]])
criminal_data

# %%
criminal_data
# Out:
# [['0', 'George_HW_Bush'],
#  ['1', 'Michael_Schumacher'],
#  ['2', 'Paul_ONeill'],
#  ['3', 'John_Manley'],
#  ['4', 'Tiger_Woods'],
#  ['5', 'Arminio_Fraga'],
#  ['6', 'Gordon_Brown'],
#  ['7', 'Igor_Ivanov'],
#  ['8', 'Li_Peng'],
#  ['9', 'John_Howard'],
#  ['10', 'Bob_Graham'],
#  ['11', 'Tommy_Haas'],
#  ['12', 'Pervez_Musharraf'],
#  ['13', 'JK_Rowling'],
#  ['14', 'Edmund_Stoiber'],
#  ['15', 'Bill_Clinton'],
#  ['16', 'Yoko_Ono'],
#  ['17', 'Larry_Brown'],
#  ['18', 'Michael_Chang'],
#  ['19', 'James_Kelly'],
#  ['20', 'Ann_Veneman'],
#  ['21', 'Jose_Serra'],
#  ['22', 'Justin_Timberlake'],
#  ['23', 'Lance_Armstrong'],
#  ['24', 'Tom_Daschle'],
#  ['25', 'Shimon_Peres'],
#  ['26', 'Bill_McBride'],
#  ['27', 'Vojislav_Kostunica'],
#  ['28', 'Atal_Bihari_Vajpayee'],
#  ['29', 'Jackie_Chan'],
#  ['30', 'Kofi_Annan'],
#  ['31', 'Alejandro_Toledo'],
#  ['32', 'Robert_Duvall'],
#  ['33', 'Bill_Simon'],
#  ['34', 'Sergio_Vieira_De_Mello'],
#  ['35', 'Hamid_Karzai'],
# ...

# %%
for i in test:
  print(i[0])

# %%
import requests
import json
import psycopg2
import os
import random
url='https://upload-dimg.herokuapp.com/upload/image'
for i in criminal_data:
  with open('facenet_train/'+i[0]+'/'+os.listdir('facenet_train/'+i[0])[0], 'rb') as img:
    name_img= os.path.basename('facenet_train/'+i[0]+'/'+os.listdir('facenet_train/'+i[0])[0])
    #print(name_img,i[0])
    files= {'image': (name_img,img,'multipart/form-data',{'Expires': '0'}) }
    with requests.Session() as s:
      r = s.post(url,files=files)
      rsrc=r.json()['url']
      conn = psycopg2.connect(database = "dbduur4vdlukem", user = "wievmwebfpihpt", password = "5a91f479409d0c0c4be99fb3a02862b995ca0663e7072d46937ea9a4719591a9", host = "ec2-34-197-141-7.compute-1.amazonaws.com", port = "5432")
      cur = conn.cursor()
      severity=random.randint(0,70)
      cur.execute("INSERT INTO criminals (gender, name, severity,picture) \
                        VALUES(%s,%s,%s,%s)",('Male',i[1],severity,rsrc))
      print("INSERT INTO criminals (gender, name, severity,picture) \
                        VALUES(%s,%s,%s,%s)",('Male',i[1],severity,rsrc))
      conn.commit()
conn.close()

# %% [markdown]
# **Testing and Updating the database**

# %%
for i in os.listdir('facenet_test'):
  path='facenet_test/'+i
  s=int(i)
  s=s-12
  print('class: ',str(s))
  # !python -m inference.classifier --image-path $path

# %%
actual=[147,147,147,147]
